# %%
import os
import main
import numpy as np
import pandas as pd

df = pd.read_csv('/host/corin/tank/jonah/pmat/src_hipp/src/workspaces/supplementary_data.csv')
subjects = df['id'].tolist()

for subject in subjects:

    if os.path.exists(f'/host/corin/tank/jonah/MPN/analyses/hipp_system_mapping/output_HCPD/{subject}/features.csv'):
        continue
    print(subject)

    config = {
        'subject':subject,
        'output':'/host/corin/tank/jonah/MPN/analyses/hipp_system_mapping/output_HCPD',

        'path_hipp_systems_L':f'/host/corin/tank/jonah/pmat/results/{subject}/hipp_systems.L.label.gii',
        'path_hipp_systems_R':f'/host/corin/tank/jonah/pmat/results/{subject}/hipp_systems.R.label.gii',

        'path_hipp_xs_L':f'/host/corin/tank/jonah/pmat/results/{subject}/hipp_dtseries_smoothed.L.func.gii',
        'path_hipp_xs_R':f'/host/corin/tank/jonah/pmat/results/{subject}/hipp_dtseries_smoothed.R.func.gii',

        'path_ctx_xs_L':f'/host/corin/tank/jonah/pmat/results/{subject}/surface_dtseries_smoothed.L.func.gii',
        'path_ctx_xs_R':f'/host/corin/tank/jonah/pmat/results/{subject}/surface_dtseries_smoothed.R.func.gii',

        'path_hipp_surf_area_L':f'/host/corin/tank/jonah/pmat/data/hippunfold_output/hippunfold/sub-{subject}/surf/sub-{subject}_hemi-L_space-T1w_den-0p5mm_label-hipp_surfarea.shape.gii',
        'path_hipp_surf_area_R':f'/host/corin/tank/jonah/pmat/data/hippunfold_output/hippunfold/sub-{subject}/surf/sub-{subject}_hemi-R_space-T1w_den-0p5mm_label-hipp_surfarea.shape.gii',

        'path_ctx_surf_area_L':f'/host/corin/tank/jonah/pmat/data/surface_areas/sub-{subject}_surface_area.L.func.gii',
        'path_ctx_surf_area_R':f'/host/corin/tank/jonah/pmat/data/surface_areas/sub-{subject}_surface_area.R.func.gii'
    }

    main.run_pipeline(config)
# Out:
# HCD0001305
# HCD0022919
# HCD0026119
# HCD0029630
# HCD0031617
# HCD0042420
# HCD0051825
# HCD0069238
# HCD0071831
# HCD0075435
# HCD0110411
# HCD0111716
# HCD0118528
# HCD0119429
# HCD0121719
# HCD0123925
# HCD0124725
# HCD0125424
# HCD0128935
# HCD0129937
# HCD0130821
# HCD0135831
# HCD0143426
# HCD0145733
# HCD0146331
# HCD0147333
# HCD0161327
# HCD0182941
# HCD0183438
# HCD0183539
# HCD0185644
# HCD0197045
# HCD0203620
# HCD0214423
# HCD0224123
# HCD0225529
# HCD0225630
# HCD0236130
# HCD0236635
# HCD0244230
# HCD0245636
# HCD0247438
# HCD0248440
# HCD0259243
# HCD0259546
# HCD0267242
# HCD0267747
# HCD0271031
# HCD0277447
# HCD0288250
# HCD0294245
# HCD0295146
# HCD0295954
# HCD0298758
# HCD0311118
# HCD0311320
# HCD0328842
# HCD0330021
# HCD0338441
# HCD0338744
# HCD0343333
# HCD0353538
# HCD0370639
# HCD0372542
# HCD0382343
# HCD0383143
# HCD0392649
# HCD0394350
# HCD0394754
# HCD0401725
# HCD0403224
# HCD0406230
# HCD0418338
# HCD0425335
# HCD0429343
# HCD0469658
# ...
