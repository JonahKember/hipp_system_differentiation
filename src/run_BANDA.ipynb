# %%
import main
import numpy as np
import pandas as pd

df = pd.read_csv('/host/corin/tank/jonah/MPN/subjects.csv')

# Remove subjects without all hippocampal systems mapped.
df = df[~np.isin(df.id, ['BANDA059','BANDA181'])]
subjects = df['id'].tolist()


for subject in subjects:

    print(subject)

    config = {
        'subject':subject,
        'output':'/host/corin/tank/jonah/MPN/analyses/hipp_system_mapping/output_BANDA',

        'path_hipp_systems_L':f'/host/corin/tank/jonah/MPN/analyses/hipp_mapping/output/{subject}/hipp_systems.L.label.gii',
        'path_hipp_systems_R':f'/host/corin/tank/jonah/MPN/analyses/hipp_mapping/output/{subject}/hipp_systems.R.label.gii',

        'path_hipp_xs_L':f'/host/corin/tank/jonah/MPN/analyses/cleaning/output/{subject}/hipp_dtseries_smoothed.L.func.gii',
        'path_hipp_xs_R':f'/host/corin/tank/jonah/MPN/analyses/cleaning/output/{subject}/hipp_dtseries_smoothed.R.func.gii',

        'path_ctx_xs_L':f'/host/corin/tank/jonah/MPN/analyses/cleaning/output/{subject}/surface_dtseries_smoothed.L.func.gii',
        'path_ctx_xs_R':f'/host/corin/tank/jonah/MPN/analyses/cleaning/output/{subject}/surface_dtseries_smoothed.R.func.gii',

        'path_hipp_surf_area_L':f'/host/corin/tank/jonah/MPN/analyses/hipp_unfold/output/hippunfold/sub-{subject}/surf/sub-{subject}_hemi-L_space-T1w_den-0p5mm_label-hipp_surfarea.shape.gii',
        'path_hipp_surf_area_R':f'/host/corin/tank/jonah/MPN/analyses/hipp_unfold/output/hippunfold/sub-{subject}/surf/sub-{subject}_hemi-R_space-T1w_den-0p5mm_label-hipp_surfarea.shape.gii',

        'path_ctx_surf_area_L':f'/host/corin/tank/jonah/MPN/analyses/hipp_system_mapping/old/output/{subject}/cortex_surface_area.L.func.gii',
        'path_ctx_surf_area_R':f'/host/corin/tank/jonah/MPN/analyses/hipp_system_mapping/old/output/{subject}/cortex_surface_area.R.func.gii'
    }

    main.run_pipeline(config)
# Out:
# BANDA001
# BANDA002
# BANDA003
# BANDA004
# BANDA005
# BANDA007
# BANDA008
# BANDA009
# BANDA010
# BANDA011
# BANDA012
# BANDA013
# BANDA014
# BANDA015
# BANDA016
# BANDA017
# BANDA018
# BANDA019
# BANDA020
# BANDA021
# BANDA022
# BANDA023
# BANDA024
# BANDA025
# BANDA026
# BANDA027
# BANDA028
# BANDA029
# BANDA030
# BANDA031
# BANDA032
# BANDA033
# BANDA034
# BANDA035
# BANDA036
# BANDA037
# BANDA038
# BANDA039
# BANDA040
# BANDA041
# BANDA042
# BANDA043
# BANDA044
# BANDA045
# BANDA046
# BANDA047
# BANDA048
